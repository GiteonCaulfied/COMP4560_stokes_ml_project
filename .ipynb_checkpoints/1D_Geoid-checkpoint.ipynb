# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T

import os
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler

from sklearn.preprocessing import MinMaxScaler

# %%
n_epoch = 100
batch_size = 4
lr = 1e-2
betas = (0.9, 0.999)

if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

print("Current device is ",device)

# Fit the MinMaxScalar
output_for_Scalar = np.load("Data/Geoid/1k/output.npy")
scaler = MinMaxScaler()
scaler.fit(output_for_Scalar)
print("Fit the output range to [0,1] using MinMaxscaler")

# make results determinstic
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# Current device is  cpu
# Fit the output range to [0,1] using MinMaxscaler

# %%
class KMNIST(Dataset):
    
    def __init__(self, input_path, output_path):
        # Load the input and output
        input_data = np.load(input_path)
        output_data = scaler.transform(np.load(output_path))
        
        self.input = input_data
        self.output = output_data
        
    def __len__(self):
        return len(self.input)

    def __getitem__(self, index):
        input_item = self.input[index]
        output_item = self.output[index]
        
        return input_item, output_item

# %%
testingAndValidation_split = 0.2
validation_split = 0.1

# Load the input and output as a complete dataset
geoid_dataset = KMNIST(
    "Data/Geoid/1k/input.npy",
    "Data/Geoid/1k/output.npy",
)

# Creating data indices for training, testing and validation splits
# Reference: https://stackoverflow.com/questions/50544730/how-do-i-split-a-custom-dataset-into-training-and-test-datasets
geoid_dataset_size = len(geoid_dataset)
geoid_indices = list(range(geoid_dataset_size))

geoid_training_testing_split = int(np.floor(testingAndValidation_split * geoid_dataset_size))
geoid_testing_validation_split = int(np.floor(validation_split * geoid_dataset_size))

np.random.shuffle(geoid_indices)
geoid_train_indices, geoid_val_indices ,geoid_test_indices = geoid_indices[geoid_training_testing_split:], geoid_indices[:geoid_testing_validation_split], geoid_indices[geoid_testing_validation_split:geoid_training_testing_split] 

# Creating data samplers
geoid_train_sampler = SubsetRandomSampler(geoid_train_indices)
geoid_test_sampler = SubsetRandomSampler(geoid_test_indices)
geoid_valid_sampler = SubsetRandomSampler(geoid_val_indices)

geoid_train_loader = DataLoader(
    dataset=geoid_dataset,
    batch_size = batch_size,
    sampler=geoid_train_sampler,
)

geoid_test_loader = DataLoader(
    dataset=geoid_dataset,
    batch_size = batch_size,
    sampler=geoid_test_sampler,
)

geoid_validation_loader = DataLoader(
    dataset=geoid_dataset,
    batch_size = batch_size,
    sampler=geoid_valid_sampler,
)

print("Training data, testing data and validation data is spilt into 8:1:1")
# Out:
# Training data, testing data and validation data is spilt into 8:1:1

# %%
'''
train_input, train_output = next(iter(geoid_train_loader))

print(f"Feature batch shape: {train_input.size()}")
print(f"Labels batch shape: {train_output.size()}")

test_index = 1
train_input_batch_sample = train_input[test_index]
train_output_batch_sample = train_output[test_index]

print(f"Input: {train_input_batch_sample}")
print(f"Output: {train_output_batch_sample}")
'''
# Out:
# '\ntrain_input, train_output = next(iter(geoid_train_loader))\n\nprint(f"Feature batch shape: {train_input.size()}")\nprint(f"Labels batch shape: {train_output.size()}")\n\ntest_index = 1\ntrain_input_batch_sample = train_input[test_index]\ntrain_output_batch_sample = train_output[test_index]\n\nprint(f"Input: {train_input_batch_sample}")\nprint(f"Output: {train_output_batch_sample}")\n'

# %%
voutput = np.load("Data/Geoid/1k/output.npy")

nmodels, _ = voutput.shape

plt.figure(figsize=(12, 6))

# Just plot every 100th model input and output to observe the pattern
for i in range(1, nmodels, 100):

    plt.plot(voutput[i, :])

plt.show()

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()    
        self.fc1 = nn.Linear(257, 200)  
        self.fc2 = nn.Linear(200, 150)   
        self.fc3 = nn.Linear(150, 100)
        self.fc4 = nn.Linear(100, 60)
        self.tanh = nn.Tanh()
    
    def forward(self, x):                              
        x = x.to(torch.float32)
        out = self.fc1(x)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        out = self.tanh(out)
        out = self.fc4(out)
        return out

# %%
def train(model, train_loader, val_loader, device, optimizer, n_epoch):
    
    criterion = nn.MSELoss()
    
    minimum_validation_loss = 10000000
    maximum_validation_accuracy = -1

    # n_epoch times of iterations
    for epoch in range(n_epoch):

        running_loss = 0.0

        model.train()
        
        for data in train_loader:
            # get a batch of inputs and labels
            inputs, labels = data[0].to(device), data[1].to(device)

            # zero the parameter gradients
            optimizer.zero_grad(set_to_none=True)

            # Get output features, calculate loss and optimize
            outputs = model(inputs)
            loss = criterion(outputs.float(), labels.float())
            
            loss.backward()
            optimizer.step()

            # Add to the total training loss
            running_loss += loss.item()

        # print some statistics
        print(epoch+1,"epochs have finished")
        print("Current training loss is ",running_loss)
        running_loss = 0.0

        # Valiadation
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            valid_loss = 0.0
            for data in val_loader:
                images, labels = data[0].to(device), data[1].to(device)

                # Get output features and calculate loss
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Add to the validation loss
                valid_loss += loss.item()

            # Calculate valiadation accuracy and print Validation statistics
            print("Validation loss for this epoch is",valid_loss)

        # Update the statistics for the best model
        if valid_loss <= minimum_validation_loss:
            minimum_validation_loss = valid_loss

        # Store to different paths for different models
        
        #PATH = 'geoid_model_{:02d}.pth'.format(epoch+1)

        #torch.save(model.state_dict(), PATH)
        #print("This model is now saved to Path:",PATH)
        print()
    
    # Training finished, print the statistics for the best model
    print('Finished Training')
    print("Best model has a validation loss of ",minimum_validation_loss)

# %%
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas)

# %%
train(model, geoid_train_loader, geoid_validation_loader, device, optimizer, n_epoch)
# Out:
# 1 epochs have finished
# Current training loss is  31.613987110555172
# Validation loss for this epoch is 3.1381135076361226
#
# 2 epochs have finished
# Current training loss is  31.086776558309793
# Validation loss for this epoch is 3.6263670554705554
#
# 3 epochs have finished
# Current training loss is  28.38509305845946
# Validation loss for this epoch is 3.2212177334552985
#
# 4 epochs have finished
# Current training loss is  26.04087959229946
# Validation loss for this epoch is 2.565340506463704
#
# 5 epochs have finished
# Current training loss is  26.833545109257102
# Validation loss for this epoch is 2.170847879179426
#
# 6 epochs have finished
# Current training loss is  28.570558320730925
# Validation loss for this epoch is 2.9999604386277983
#
# 7 epochs have finished
# Current training loss is  27.89849024452269
# Validation loss for this epoch is 2.2186164768522523
#
# 8 epochs have finished
# Current training loss is  29.124679806642234
# Validation loss for this epoch is 7.890348414089147
#
# 9 epochs have finished
# Current training loss is  36.18895630445331
# Validation loss for this epoch is 2.5789996401867588
#
# 10 epochs have finished
# Current training loss is  30.428544492460787
# Validation loss for this epoch is 2.6315448962638888
#
# 11 epochs have finished
# Current training loss is  25.320695302914828
# Validation loss for this epoch is 2.634969380189812
#
# 12 epochs have finished
# Current training loss is  28.73436842672527
# Validation loss for this epoch is 2.9498275812003047
#
# 13 epochs have finished
# Current training loss is  24.808975134510547
# Validation loss for this epoch is 2.5631338578388543
#
# 14 epochs have finished
# Current training loss is  29.77711138385348
# Validation loss for this epoch is 3.63992867480513
#
# 15 epochs have finished
# Current training loss is  38.16317611653358
# Validation loss for this epoch is 2.744618227608088
#
# 16 epochs have finished
# Current training loss is  29.445870615076274
# Validation loss for this epoch is 3.1100781770107595
#
# 17 epochs have finished
# Current training loss is  24.96687808074057
# Validation loss for this epoch is 2.545624192048174
#
# 18 epochs have finished
# Current training loss is  28.793907000683248
# Validation loss for this epoch is 7.933316403455668
#
# 19 epochs have finished
# Current training loss is  31.103173788636923
# Validation loss for this epoch is 4.1986377485097846
#
# 20 epochs have finished
# Current training loss is  27.57211488392204
# Validation loss for this epoch is 2.3713542699337395
#
# 21 epochs have finished
# Current training loss is  27.221434927079827
# Validation loss for this epoch is 2.3007770129940393
#
# 22 epochs have finished
# Current training loss is  28.700707433745265
# Validation loss for this epoch is 2.132790883477063
#
# 23 epochs have finished
# Current training loss is  28.46083644684404
# Validation loss for this epoch is 2.801689835568965
#
# 24 epochs have finished
# Current training loss is  27.089625612832606
# Validation loss for this epoch is 2.9216445867767025
#
# 25 epochs have finished
# Current training loss is  29.12083430122584
# Validation loss for this epoch is 2.995974281291935
#
# 26 epochs have finished
# Current training loss is  28.106898023746908
# Validation loss for this epoch is 5.937059795981239
#
# 27 epochs have finished
# Current training loss is  27.023030508309603
# Validation loss for this epoch is 2.94902048085897
#
# 28 epochs have finished
# Current training loss is  30.77376082073897
# Validation loss for this epoch is 2.3532106553476324
#
# 29 epochs have finished
# Current training loss is  31.13240684941411
# Validation loss for this epoch is 2.7800133858535063
#
# 30 epochs have finished
# Current training loss is  27.020392490550876
# Validation loss for this epoch is 2.804681950532969
#
# 31 epochs have finished
# Current training loss is  24.119069614447653
# Validation loss for this epoch is 2.7143917621251314
#
# 32 epochs have finished
# Current training loss is  28.91335303336382
# Validation loss for this epoch is 4.317723728527095
#
# 33 epochs have finished
# Current training loss is  36.429174148477614
# Validation loss for this epoch is 4.882987725138808
#
# 34 epochs have finished
# Current training loss is  28.718132602982223
# Validation loss for this epoch is 2.4565504168920254
#
# 35 epochs have finished
# Current training loss is  31.784851188771427
# Validation loss for this epoch is 3.450798894810156
#
# 36 epochs have finished
# Current training loss is  29.264169995673
# Validation loss for this epoch is 3.8102803938253786
#
# 37 epochs have finished
# Current training loss is  29.728659458458424
# Validation loss for this epoch is 2.913818496854641
#
# 38 epochs have finished
# Current training loss is  32.7216628130991
# Validation loss for this epoch is 3.9163109088865014
#
# 39 epochs have finished
# Current training loss is  31.26700962614268
# Validation loss for this epoch is 2.9452301318771137
#
# 40 epochs have finished
# Current training loss is  29.105338107561693
# Validation loss for this epoch is 2.6694111060829866
#
# 41 epochs have finished
# Current training loss is  26.656496892683208
# Validation loss for this epoch is 2.2019402286548133
#
# 42 epochs have finished
# Current training loss is  29.661969664506614
# Validation loss for this epoch is 3.0388712071207835
#
# 43 epochs have finished
# Current training loss is  26.125833354890347
# Validation loss for this epoch is 3.02670639166715
#
# 44 epochs have finished
# Current training loss is  27.76036761747673
# Validation loss for this epoch is 7.61210574946823
#
# 45 epochs have finished
# Current training loss is  32.658211862668395
# Validation loss for this epoch is 2.432113142955028
#
# 46 epochs have finished
# Current training loss is  32.64521011337638
# Validation loss for this epoch is 3.0475823626806453
#
# 47 epochs have finished
# Current training loss is  27.006828515790403
# Validation loss for this epoch is 5.628375001584265
#
# 48 epochs have finished
# Current training loss is  23.870411843061447
# Validation loss for this epoch is 2.4247528811302295
#
# 49 epochs have finished
# Current training loss is  35.02810310572386
# Validation loss for this epoch is 2.2369275257074004
#
# 50 epochs have finished
# Current training loss is  30.975753504782915
# Validation loss for this epoch is 4.153855925505087
#
# 51 epochs have finished
# Current training loss is  27.695725727360696
# Validation loss for this epoch is 4.759509766055139
#
# 52 epochs have finished
# Current training loss is  28.59623816702515
# Validation loss for this epoch is 2.258058462213761
#
# 53 epochs have finished
# Current training loss is  27.342972834594548
# Validation loss for this epoch is 3.0401203520859212
#
# 54 epochs have finished
# Current training loss is  28.12079193815589
# Validation loss for this epoch is 4.097634553587787
#
# 55 epochs have finished
# Current training loss is  30.2021327521652
# Validation loss for this epoch is 8.317753989815351
#
# 56 epochs have finished
# Current training loss is  32.75895590335131
# Validation loss for this epoch is 5.644433979651629
#
# 57 epochs have finished
# Current training loss is  33.11406593117863
# Validation loss for this epoch is 3.499804574884414
#
# 58 epochs have finished
# Current training loss is  28.751824195496738
# Validation loss for this epoch is 3.003214242935793
#
# 59 epochs have finished
# Current training loss is  27.078796655405313
# Validation loss for this epoch is 2.8232123822141886
#
# 60 epochs have finished
# Current training loss is  29.62591382372193
# Validation loss for this epoch is 2.776703813712917
#
# 61 epochs have finished
# Current training loss is  32.52763068117201
# Validation loss for this epoch is 3.38336646810195
#
# 62 epochs have finished
# Current training loss is  26.370511369779706
# Validation loss for this epoch is 2.795019165981642
#
# 63 epochs have finished
# Current training loss is  33.988697030581534
# Validation loss for this epoch is 5.899911286407342
#
# 64 epochs have finished
# Current training loss is  25.90575628168881
# Validation loss for this epoch is 4.222497762017297
#
# 65 epochs have finished
# Current training loss is  28.911701732315123
# Validation loss for this epoch is 5.827961325145204
#
# 66 epochs have finished
# Current training loss is  32.22091092215851
# Validation loss for this epoch is 12.058987881059975
#
# 67 epochs have finished
# Current training loss is  26.320520797744393
# Validation loss for this epoch is 3.423357385424885
#
# 68 epochs have finished
# Current training loss is  35.41364013776183
# Validation loss for this epoch is 2.838952625884928
# 69 epochs have finished
# Current training loss is  28.07117074355483
# Validation loss for this epoch is 3.9769355660639616
#
# 70 epochs have finished
# Current training loss is  24.796572207007557
# Validation loss for this epoch is 2.888060727489681
#
# 71 epochs have finished
# Current training loss is  27.67422663839534
# Validation loss for this epoch is 4.6857594895455055
#
# 72 epochs have finished
# Current training loss is  26.583398479036987
# Validation loss for this epoch is 2.801126784622001
#
# 73 epochs have finished
# Current training loss is  29.8321977192536
# Validation loss for this epoch is 5.062453859033775
#
# 74 epochs have finished
# Current training loss is  27.929666795767844
# Validation loss for this epoch is 2.962335810814664
#
# 75 epochs have finished
# Current training loss is  29.16283841151744
# Validation loss for this epoch is 2.955044621966652
#
# 76 epochs have finished
# Current training loss is  29.26646289252676
# Validation loss for this epoch is 2.2284185518940536
#
# 77 epochs have finished
# Current training loss is  31.096071678213775
# Validation loss for this epoch is 4.221019970592148
#
# 78 epochs have finished
# Current training loss is  29.362098602112383
# Validation loss for this epoch is 3.738091919425957
#
# 79 epochs have finished
# Current training loss is  22.552525178994983
# Validation loss for this epoch is 2.562968545956677
#
# 80 epochs have finished
# Current training loss is  32.16324406862259
# Validation loss for this epoch is 3.8861024032366935
#
# 81 epochs have finished
# Current training loss is  27.640000453218818
# Validation loss for this epoch is 5.818147766037607
#
# 82 epochs have finished
# Current training loss is  26.932308367453516
# Validation loss for this epoch is 2.390064601465818
#
# 83 epochs have finished
# Current training loss is  25.570261337794363
# Validation loss for this epoch is 3.583949157142708
#
# 84 epochs have finished
# Current training loss is  33.97411100752652
# Validation loss for this epoch is 3.4996988839928598
#
# 85 epochs have finished
# Current training loss is  34.022180194500834
# Validation loss for this epoch is 4.437374214869464
#
# 86 epochs have finished
# Current training loss is  33.21241805003956
# Validation loss for this epoch is 3.9138810379674096
#
# 87 epochs have finished
# Current training loss is  34.521260131150484
# Validation loss for this epoch is 3.15036103731731
#
# 88 epochs have finished
# Current training loss is  27.63312012166716
# Validation loss for this epoch is 2.934794735804718
#
# 89 epochs have finished
# Current training loss is  29.863457300933078
# Validation loss for this epoch is 2.543034600184729
#
# 90 epochs have finished
# Current training loss is  31.2502980241552
# Validation loss for this epoch is 6.0835858644447995
#
# 91 epochs have finished
# Current training loss is  36.326854401733726
# Validation loss for this epoch is 3.456987933945412
#
# 92 epochs have finished
# Current training loss is  32.58049450884573
# Validation loss for this epoch is 3.030895526372904
#
# 93 epochs have finished
# Current training loss is  28.84320631995797
# Validation loss for this epoch is 3.8066399295470426
#
# 94 epochs have finished
# Current training loss is  26.498656667768955
# Validation loss for this epoch is 5.019356220585095
#
# 95 epochs have finished
# Current training loss is  26.549730224069208
# Validation loss for this epoch is 3.2378291503724284
#
# 96 epochs have finished
# Current training loss is  30.87132341042161
# Validation loss for this epoch is 3.2573128140545955
#
# 97 epochs have finished
# Current training loss is  28.999503879109398
# Validation loss for this epoch is 3.6191111007291417
#
# 98 epochs have finished
# Current training loss is  29.722383274696767
# Validation loss for this epoch is 3.178892302327103
#
# 99 epochs have finished
# Current training loss is  31.98098200559616
# Validation loss for this epoch is 2.697707182715724
#
# 100 epochs have finished
# Current training loss is  27.0774418823421
# Validation loss for this epoch is 4.299095573328683
#
# Finished Training
# Best model has a validation loss of  2.132790883477063

# %%
# Testing for 10 data entries in the test dataset
for i in range(20):    
    test_input, test_output = next(iter(geoid_test_loader))
    
    test_index = 0
    test_input_batch_sample = test_input[test_index]
    test_output_batch_sample = test_output[test_index].detach().numpy()
    predicted_output = model(test_input_batch_sample).detach().numpy()
    
    plt.figure(figsize=(12, 6))

    plt.plot(scaler.inverse_transform([test_output_batch_sample])[0], label='Data Output')
    plt.plot(scaler.inverse_transform([predicted_output])[0], label='Predicted Output')
    plt.legend()

    plt.show()
